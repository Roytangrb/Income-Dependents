# %%
#农村居民平均每个劳动力负担人口

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

df = pd.read_csv('农村居民中等偏上户平均每个劳动力负担人口.csv')
'''
df.columns: ['种类列', 'region', 'unit', 'time', 'regionName', 'value', 'type']
df.index.unique(): ['农村居民中等偏上户平均每个劳动力负担人口', '农村居民低收入户平均每个劳动力负担人口', '农村居民中等收入户平均每个劳动力负担人口',
       '农村居民高收入户平均每个劳动力负担人口', '农村居民平均每个劳动力负担人口(含本人)', '农村居民中等偏下户平均每个劳动力负担人口']
'''
df = df.reset_index()
df.columns = ['种类列', 'region', 'unit', 'time', 'regionName', 'value', 'type', 'dummy']
df = df[['种类列', 'unit', 'time', 'regionName', 'value']]
df
# Out:
#                      种类列 unit  time regionName     value
# 0   农村居民中等偏上户平均每个劳动力负担人口    人  2012         中国  1.349864
# 1   农村居民中等偏上户平均每个劳动力负担人口    人  2011         中国  1.341628
# 2   农村居民中等偏上户平均每个劳动力负担人口    人  2010         中国  1.340000
# 3   农村居民中等偏上户平均每个劳动力负担人口    人  2009         中国  1.350000
# 4   农村居民中等偏上户平均每个劳动力负担人口    人  2008         中国  1.360000
# 5   农村居民中等偏上户平均每个劳动力负担人口    人  2007         中国  1.360000
# 6   农村居民中等偏上户平均每个劳动力负担人口    人  2006         中国  1.370000
# 7   农村居民中等偏上户平均每个劳动力负担人口    人  2005         中国  1.390000
# 8   农村居民中等偏上户平均每个劳动力负担人口    人  2004         中国  1.400000
# 9   农村居民中等偏上户平均每个劳动力负担人口    人  2003         中国  1.410000
# 10  农村居民中等偏上户平均每个劳动力负担人口    人  2002         中国  1.450000
# 11   农村居民低收入户平均每个劳动力负担人口    人  2012         中国  1.508373
# 12   农村居民低收入户平均每个劳动力负担人口    人  2011         中国  1.517526
# 13   农村居民低收入户平均每个劳动力负担人口    人  2010         中国  1.470000
# 14   农村居民低收入户平均每个劳动力负担人口    人  2009         中国  1.490000
# ...

# %%
import numpy as np

df_high = df[df['种类列'] == '农村居民高收入户平均每个劳动力负担人口']
df_low = df[df['种类列'] == '农村居民低收入户平均每个劳动力负担人口']
df_upper = df[df['种类列'] == '农村居民中等偏上户平均每个劳动力负担人口']
df_lower = df[df['种类列'] == '农村居民中等偏下户平均每个劳动力负担人口']
df_middle = df[df['种类列'] == '农村居民中等收入户平均每个劳动力负担人口']
df_avg = df[df['种类列'] == '农村居民中等偏上户平均每个劳动力负担人口']

plt.scatter(df_avg['time'], df_avg['value'], s = 50, c='lightgreen', label='Average')

plt.plot(df_high['time'], df_high['value'], '-o', markersize = 4, c='black', alpha=0.6, label='High Income')
plt.plot(df_upper['time'], df_upper['value'], '-o', markersize = 4, c='blue',alpha=0.7, label='Medium Upper Income')
plt.plot(df_middle['time'], df_middle['value'], '-o', markersize = 4, c='blue',alpha=0.5, label='Medium Income')
plt.plot(df_lower['time'], df_lower['value'], '-o', markersize = 4, c='blue',alpha=0.3, label='Medium Lower Income')
plt.plot(df_low['time'], df_low['value'], '-o', markersize = 4, c='blue',alpha=0.1, label='Low Income')

plt.title('Number of Dependents per Labour Force in Rural Areas, China')
plt.xlabel('Year')
plt.ylabel('Number of dependents (self included)')
plt.legend(loc=1, frameon=False)

ax = plt.gca()
_ = ax.axis([2001, 2013, 1, 2])
_ = plt.xticks(np.arange(2002, 2013, 1))
ax.text(2002, 1.1, '*Note: Overall average values are almost identical to \n           the values of "Medium Upper Income" class')
# Out:
# <img src="data:image/png;base64,..." width="640">
